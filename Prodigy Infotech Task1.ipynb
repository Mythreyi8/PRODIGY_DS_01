# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df=pd.read_csv(r"D:\Prodigy\new.csv")

# %%
df
# Out:
#               Country Name Country Code  Population total   \
# 0              Afghanistan          AFG           41128771
# 1                  Albania          ALB            2777689
# 2                  Algeria          DZA           44903225
# 3           American Samoa          ASM              44273
# 4                  Andorra          AND              79824
# ..                     ...          ...                ...
# 212  Virgin Islands (U.S.)          VIR             105413
# 213     West Bank and Gaza          PSE            5043612
# 214            Yemen, Rep.          YEM           33696614
# 215                 Zambia          ZMB           20017675
# 216               Zimbabwe          ZWE           16320537
#
#      Population ages 0-14, male   Population ages 0-14, female   \
# 0                        9076426                        8662674
# 1                         228501                         220001
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Country Name                           217 non-null    object
#  1   Country Code                           217 non-null    object
#  2   Population total                       217 non-null    int64
#  3   Population ages 0-14, male             217 non-null    int64
#  4   Population ages 0-14, female           217 non-null    int64
#  5   Population ages 15-64, female          217 non-null    int64
#  6    Population ages 15-64, male           217 non-null    int64
#  7   Population ages 65 and above, female   217 non-null    int64
#  8   Population ages 65 and above, male     217 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 15.4+ KB

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Population total ',
#        'Population ages 0-14, male ', 'Population ages 0-14, female ',
#        'Population ages 15-64, female ', ' Population ages 15-64, male ',
#        'Population ages 65 and above, female ',
#        'Population ages 65 and above, male'],
#       dtype='object')

# %%
df=df.dropna()

# %%
df.head()
# Out:
#      Country Name Country Code  Population total   \
# 0     Afghanistan          AFG           41128771
# 1         Albania          ALB            2777689
# 2         Algeria          DZA           44903225
# 3  American Samoa          ASM              44273
# 4         Andorra          AND              79824
#
#    Population ages 0-14, male   Population ages 0-14, female   \
# 0                      9076426                        8662674
# 1                       228501                         220001
# 2                      7026587                        6733218
# 3                         6186                           5832
# 4                         5212                           5001
#
#    Population ages 15-64, female    Population ages 15-64, male   \
# 0                        11136302                       11268607
# 1                          932631                         933926
# 2                        13815800                       14459297
# ...

# %%
df.tail()
# Out:
#               Country Name Country Code  Population total   \
# 212  Virgin Islands (U.S.)          VIR             105413
# 213     West Bank and Gaza          PSE            5043612
# 214            Yemen, Rep.          YEM           33696614
# 215                 Zambia          ZMB           20017675
# 216               Zimbabwe          ZWE           16320537
#
#      Population ages 0-14, male   Population ages 0-14, female   \
# 212                        10252                           9965
# 213                       996263                         959125
# 214                      6813177                        6496056
# 215                      4289614                        4289272
# 216                      3316043                        3315644
#
#      Population ages 15-64, female    Population ages 15-64, male   \
# 212                           33534                          30138
# 213                         1468568                        1441495
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt 
 
  
# Define age categories
age_categories= ['0-14M', '15-64M', '65M','0-14F', '15-64F', '65F']

# Create a new DataFrame with columns for each age category
df_stacked = df[['Population ages 0-14, male ',' Population ages 15-64, male ','Population ages 65 and above, male',
                 'Population ages 0-14, female ','Population ages 15-64, female ',
                 'Population ages 65 and above, female ']].copy()
df_stacked.columns = age_categories



# Calculate the sum of each age category
total_population = df_stacked.sum()

# Create a bar chart for age distribution
plt.figure(figsize=(30,10))
plt.bar(age_categories,total_population)
plt.xlabel('Age Category')
plt.ylabel('Population Total')
plt.title('Bar Chart for Age and Gender Distribution in the Population (2022)')
plt.show()
